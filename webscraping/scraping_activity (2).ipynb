# %%
import requests
from bs4 import BeautifulSoup

# %%
# Fetch data & store it

page_count = 1
life_quotes = []
while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)
    
    soup = BeautifulSoup(res.text, "lxml")
    quotes = soup.select("div.quote")

    if not quotes:
        print("no valid pages anymore..")
        break
#saving the data
    with open(f"scraped_data/quotes{page_count}.html", "w", encoding="utf-8", errors="ignore") as f:
     f.write(res.text)
     print(f"downloaded data from page{page_count}")
#extracting useful information(life quotes and author name)
    soup = BeautifulSoup(html_content, "lxml")
    all_quotes = soup.select("div.quote")
   

    for q in all_quotes:
        all_tags = []

        for tag in q.select(".tags .tag"):
            all_tags.append(tag.get_text())

        if "life" in all_tags:
            text = q.select_one("span.text").get_text()
            author = q.select_one("small.author").get_text()
            life_quotes.append([text, author])
           
    print(f"saved all quotes with life tag and author name of page{page_count}")

    page_count = page_count + 1
# Out:
# downloaded data from page1
# saved all quotes with life tag and author name of page1
# downloaded data from page2
# saved all quotes with life tag and author name of page2
# downloaded data from page3
# saved all quotes with life tag and author name of page3
# downloaded data from page4
# saved all quotes with life tag and author name of page4
# downloaded data from page5
# saved all quotes with life tag and author name of page5
# downloaded data from page6
# saved all quotes with life tag and author name of page6
# downloaded data from page7
# saved all quotes with life tag and author name of page7
# downloaded data from page8
# saved all quotes with life tag and author name of page8
# downloaded data from page9
# saved all quotes with life tag and author name of page9
# downloaded data from page10
# saved all quotes with life tag and author name of page10
# no valid pages anymore..

# %%
life_quotes
# Out:
# [["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini'],
#  ["“I'm the one that's got to die when it's time for me to die, so let me live my life the way I want to.”",
#   'Jimi Hendrix'],
#  ['“But better to get hurt by the truth than comforted with a lie.”',
#   'Khaled Hosseini']]
